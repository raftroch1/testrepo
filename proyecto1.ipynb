# %% [markdown]
#  <h1>My Jupyter Notebook on IBM Watson Studio"</h1>

# %% [markdown]
# <b>Rafael Troche soon to be data scientist</b>

# %% [markdown]
# <i>"I am interested to be a data scientist because there's to much missued data on corporations. I could help create more efficiency, solve problems while creating a long lasting carrer path for myself" </i>

# %%
<h3> my code is going to change a string to an integer<h3>
# Out:
#   File "/tmp/wsuser/ipykernel_165/3039628956.py", line 1
#     <h3> my code is going to change a string to an integer<h3>
#     ^
# SyntaxError: invalid syntax

# %%
n="3"
print(int(n))
# Out:
# 3

# %% [markdown]
# 1. Cats
# 2. Dogs
# 3. Humans
#
#     | Example | for project 1 |
# | ----------- | ----------- |
# | this is the first row | second row |
# | some Paragraph to describe the table | more text for the table |
#
#  [for reference on how to do this](https://www.markdownguide.org/cheat-sheet/)
